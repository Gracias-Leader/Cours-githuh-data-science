# %% [markdown]
# # Data Science Tools and Ecosyste

# %% [markdown]
# Dans ce notebook, les outils et écosystèmes de la science des données sont résumés.

# %% [markdown]
# **Objectifs**
#
# - Lister les langages populaires pour la science des données
#
# - Présenter les environnements de développement open source utilisés en science des données
#
# - Montrer des exemples d’évaluation d’expressions arithmétiques en Python
#
# - Convertir des unités simples (comme minutes en heures)
#
# - Comprendre l’utilisation des cellules Markdown pour organiser un notebook

# %% [markdown]
# Certains des langages populaires que les scientifiques des données utilisent sont :
# 1. Langage R,
# 2. Python et
# 3. SQL

# %% [markdown]
# Certaines des bibliothèques couramment utilisées par les scientifiques des données incluent :
#
# 1. Numpy,
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# |Outils de la science des données|
# |--------------------------------|
# |1. Jupyter Notebook / JupyterLab|
# |2. RStudio|
# |3. VS Code (Visual Studio Code)|

# %% [markdown]
# ### Voici quelques exemples d'évaluation d'expressions arithmétiques en Python
#
# #### Addition
#    x = 10 + 5
#    print(x)
#
# #### Soustraction
#    y = 20 - 7
#    print(y)
#
# #### Mutiplication
#    z = 4 * 6
#    print(z)
#
# #### Division
#    a = 15 / 3
#    print(a)

# %% [markdown]
# Ceci est une expression arithmétique simple pour multiplier puis ajouter des entiers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# Créer une cellule de code pour convertir des minutes en heures

# %%
minutes = 200
heures = minutes/60
print(heures)
# Out:
# 3.3333333333333335
